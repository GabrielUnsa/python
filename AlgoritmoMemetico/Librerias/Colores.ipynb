# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_use()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b649a834d49e> in <module>()
#       1 from google.colab import auth
# ----> 2 auth.authenticate_use()
#
# AttributeError: module 'google.colab.auth' has no attribute 'authenticate_use'

# %%
import random

class colores:
  def __init__( self, colores = None, feed = None, N = None ):
    self.colores = colores
    self.feed = feed
    self.N = N
  
  def set_colores( self, colores ):
    self.colores = colores
  
  def get_colores( self ):
    return self.colores

  def set_feed( self, feed ):
    self.feed = feed

  def get_feed( self ):
    return self.feed

  def set_N( self, N ):
    self.N = N
  
  def get_N( self ):
    return self.N
  
  # Buscar si el color ya se encuentra en el array de colores, devuelve la posicion si lo encuentra 
  def search_color( self, newColor ):
    i = 0
    while i < self.N :
      if self.colores[i].get_color() == newColor:
        break
      i += 1
    return i
  
  # Controla que el conjunto de vertice no pertenesca a ningun color anterior
  def vertex_control( self, newVertex ):
    i = 0
    while i < self.N :
      for vtx in newVertex:
        if self.colores[i].isVertex( newVertex ):
          i = self.N
          break
      i += 1
    return i == self.N
  
  # Agrega un nuevo color( con su estructura complemta)
  def add_newColor( self, newColour ):
    if self.colores == None:
      self.colores = []
      self.N = 0
    self.colores.append( newColour )
    self.N += 1
       
  # Añade un vertice a un color espesifico
  def add_newVertex( self, newColor, addvertex ):
    self.colores[self.search_color( newColor )].addVertex( addvertex )
  
  # Elimina un color
  def remove_color( self, remColor ):
    i = 0
    while i < self.N :
      if not ( self.colores[i].get_color() == remColor ):
        i = i + 1
      else:
        break
    for i in range( self.N - 1 ):
      self.colores[i] = self.colores[i+1]
    del self.colores[ self.N ]   
    self.N -= 1
  
  # Muestra todos los colores con sus vertices
  def print_colores( self ):
    print( " Feed: " + str( self.feed ) )
    print( " N: " + str( self.N ) )
    for c in self.colores:
      print( " Color: " + str( c.get_color() ) )
      c.printVertex()

  # Retorna un set de vertices tq sean la interseccion de los anteriores colores
  def colores_intersection( self , controlVertex ):
    i = 0
    intersection = set()
    while ( i < self.N ):
      for vtx in controlVertex & self.colores[i].get_vertex():
        intersection.add( vtx )
      i += 1
    return vertex - intersection
  
'''  # Añade el color y el conjunto de vertices
  def add_NewColorVertex( self, colour, vertexs ):
    newColor = color( colour, vertexs ) 
    if self.colores == None:
      self.colores = []  
    self.colores.append( newColor )
    self.N = len( self.colores )
'''
# Out:
# '  # Añade el color y el conjunto de vertices\n  def add_NewColorVertex( self, colour, vertexs ):\n    newColor = color( colour, vertexs ) \n    if self.colores == None:\n      self.colores = []  \n    self.colores.append( newColor )\n    self.N = len( self.colores )\n'
